# %% [markdown]
# <a href="https://colab.research.google.com/github/harish377/Poojithaapp/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

IMG_SIZE = (48, 48)
BATCH_SIZE = 64

# Load training data
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode="grayscale"
)

# Load validation data
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode="grayscale"
)

# Load test data
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    "test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode="grayscale"
)

# Show classes
print("Classes:", train_data.class_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_52086/3518887108.py in <cell line: 0>()
#       6
#       7 # Load training data
# ----> 8 train_data = tf.keras.preprocessing.image_dataset_from_directory(
#       9     "train",
#      10     validation_split=0.2,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263     if seed is None:
#     264         seed = np.random.randint(1e6)
# --> 265     image_paths, labels, class_names = dataset_utils.index_directory(
#     266         directory,
#     267         labels,
#
# ...
